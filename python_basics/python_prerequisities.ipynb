# %% [markdown]
# ## PYTHON REQUIREMENTS

# %% [markdown]
# ### WE ARE GOING TO COVER PYTHON REQUIREMENTS

# %%
print("Hello World! ")
# Out:
# Hello World!

# %%
name="Amit"

# %%
Name="amit"
name==Name
# Out:
# False

# %% [markdown]
# ## INDENTATION

# %%
1+2+3+4+5+\
6+7
# Out:
# 28

# %% [markdown]
# ### \ for continuining the line

# %%
a=5 ; b=6; c= 7 ;
