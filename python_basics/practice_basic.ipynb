# %%
name = 'Kislay '

# %%
numb = 19 
height = 5.7 
is_student = True

# %%
print(numb)
# Out:
# 19

# %%
x,y,z=1,2,3

# %%
print(y)
# Out:
# 2

# %%
print(z)
# Out:
# 3

# %%
print("Hello World ")
# Out:
# Hello World

# %%
age = input("Enter your age: ")

# %%
print(age)
# Out:
# 31

# %%
type(age)
# Out:
# str

# %% [markdown]
# ## input() always return a string . If you need a number , expliciltly cast it into int( ) , float() , or any other type otherwise it will cause type error

# %%
compl = 2+3j

# %%
type (compl)
# Out:
# complex

# %%
st = '2+3j'

# %%
type(st)
# Out:
# str

# %%
x = 1_000_000

# %%
type(x)
# Out:
# int

# %%
y = 154_234_321

# %%
type(y)
# Out:
# int

# %%
c = 3+4j

# %%
print(c.real , c.imag)
pi = 3.1456
# Out:
# 3.0 4.0

# %%
isinstance(pi , float)
# Out:
# True

# %%
type(pi)
# Out:
# float

# %% [markdown]
# ## STRINGS

# %%
single = 'Hello '
double = "Hiii"
multi = """ okay so here we can use
multi line in different lines as well """

# %%
print (multi )
# Out:
#  okay so here we can use
# multi line in different lines as well

# %%
s = ' python '

# %%
print(s.upper())
print(s.capitalize())
print(len(s))
# Out:
#  PYTHON
#  python
# 8

# %%
print (s[0])

# %%
print(s[1])
# Out:
# p

# %%
print(s[-1])
print(s[-2])
# Out:
#
# n

# %%
print(s[1:6])
# Out:
# pytho

# %% [markdown]
# ### bool(x) is usually true false only for 0 , None , [] , {}

# %% [markdown]
# ### for and , or , not operator we just use eglish words not any mathematical symbols or things like that

# %% [markdown]
# ## Identity Checks

# %%
a = [1,2]
b=a 
print ( a is b )
print ( a is not b )
# Out:
# True
# False

# %%
fruits = ['apple' , ' banana ']
print('apple' in fruits )
print('mango' not in fruits )
# Out:
# True
# True
