# %% [markdown]
# ### VARIABLES

# %%
print("Hello World")
# Out:
# Hello World

# %%
age=23
Name="Amit"

# %%
Height = 5.8
print(age)
# Out:
# 23

# %%
age
# Out:
# 23

# %%
print("hey", Name)
# Out:
# hey Amit

# %%
#Hello everyone

# %%
'''hello
     amit'''
# Out:
# 'hello\n     amit'

# %%
'''Hello
amit'''
# Out:
# 'Hello\namit'

# %%
Age = 23
print(type(Age))
# Out:
# <class 'int'>

# %% [markdown]
# ### Þypecasting

# %%
Age=str(Age)

# %%
print(Age)
print(type(Age))
# Out:
# 23
# <class 'str'>

# %%
'''Every typecasting is not possible '''
# Out:
# 'Every typecasting is not possible '

# %%
'''int --> str'''
# Out:
# 'int --> str'

# %%
''' str --> int'''
# Out:
# ' str --> int'

# %%
Name = input("Enter your name: ")

# %%
print(Name)
# Out:
# Ksilay Kumar Ranjan

# %%
name = input("Enter your name ")
age = int(input("enter your age"))

# %%
print("your name is :", name , "your age is :", age)
# Out:
# your name is : Kislay Kumar Ranjan your age is : 23

# %%
val1 = int(input("Enter number 1"))

# %%
val2 = int(input("enter number 2 " ))
print(val1+val2)
# Out:
# 66

# %% [markdown]
# ### DATA TYPES

# %%
age1= input("ENter your first pnumber")
age2 = input("ENter your second number")

# %%
print(age1+age2)
# Out:
# 4132

# %%
age1 == age2
# Out:
# False

# %% [markdown]
# ### TYPES OF OPERATORS
# Floor(//)
# Exponent(a**b)

# %%
a= 18
b=5
print(a//b)
# Out:
# 3

# %% [markdown]
# ### TYPES OF DATA STRUCTURE

# %% [markdown]
# 1. LIST
# 2. TUPLE
# 3. SET
# 4. DICTIONARY
