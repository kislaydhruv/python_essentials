# %% [markdown]
# ### Task1

# %%
products = ['speaker','monitor','mouse','laptop','phones','alarm']

# %%
sample_product = ('speaker',2000,'Electronics')

# %%
print(products[1],products[-2])
# Out:
# monitor phones

# %%
products.extend(['watch','remote'])
products
# Out:
# ['speaker', 'monitor', 'mouse', 'laptop', 'phones', 'alarm', 'watch', 'remote']

# %% [markdown]
# ## TASK2

# %%
catogries_set={'electronics','electronics','electronics','electronics'}
catogries_set
# Out:
# {'electronics'}

# %%
catogries_set.add('electronics')

# %%
catogries_set
k={'electronics'}

# %%
catogries_set.isdisjoint(k)
# Out:
# False

# %% [markdown]
# ## Task 3

# %%
price_dict={
    'watch':15000,
    'phone':50000,
    'bracelet':5000,
    'speaker':7000,
    'pen':10,
    'tumbler':500
}

# %%
price_dict['tumbler']=600

# %%
del price_dict['pen']

# %%
price_dict
# Out:
# {'watch': 15000,
#  'phone': 50000,
#  'bracelet': 5000,
#  'speaker': 7000,
#  'tumbler': 600}

# %%
count = 0
summ = 0 
for key,value in price_dict.items():
    summ = summ + value
    count = count+1

print(summ/count)
# Out:
# 15520.0
