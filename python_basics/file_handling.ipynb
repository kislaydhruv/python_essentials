# %% [markdown]
# ## File Handling

# %%
 # Always use 'with' - auto-closes even on exceptions

# %%
with open ('data.txt','r') as f :
    content = f.read()
    print(content)
# Out:
# Hello world we are doing file handling

# %%
with open ('sample.txt','r') as f :
    #Read entire file as one string 
    content = f.read()
    print(content)

    #read into list of lines
    f.seek(0) # reset to start 
    lines = f.readlines()
    print(lines)

    #read line by line (memory-efficient for large files)
    f.seek(0)
    for line in f:
        print(line.strip()) #strip() removes \n
# Out:
# This is sample txt file to learn more about file handling
# We have to check the readlines
# How reading goes in multiple lines
#
# ['This is sample txt file to learn more about file handling\n', 'We have to check the readlines \n', 'How reading goes in multiple lines\n']
# This is sample txt file to learn more about file handling
# We have to check the readlines
# How reading goes in multiple lines

# %%
with open ('output.txt','w') as f :
    f.write('hello, file! \n')
    f.writelines(['line 1\n', 'Line 2\n'])

# %%
with open ('output.text','a') as f :
    f.write('New Line added \n')
