# %%
class Dog:
    species = 'Canis familiaris'


    def __init__ (self, name, age): # __init__ shows constructor and we use self as well also here arguments are name and age
        self.name = name 
        self.age = age 

    def bark(self) : #here there is no argument 
        # self efers to the current instance . Python passes it automatically - you mever pass it manually when calling a method 

        print(f'{self.name} says: Woof! ')

# %%
d1 = Dog ( 'Buddy',3)
d2 = Dog ('Max',5)
d1.bark()
print(Dog.species)
# Out:
# Buddy says: Woof!
# Canis familiaris

# %%
## Instance method "self" ; class method "cls" ; static method"none"
