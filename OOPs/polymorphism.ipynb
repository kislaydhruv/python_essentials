# %%
class Cat :
    def sound(self) : return 'meow!'

class Dog :
    def sound(self) : return 'Woof!'

class Robot : 
    def sound(self): return 'Beep! '

# %%
for obj in [ Cat(), Dog() , Robot()]:
    print(obj.sound())
# Out:
# meow!
# Woof!
# Beep!

# %%
## We are basically overriding
